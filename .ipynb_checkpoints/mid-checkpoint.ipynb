# %%
import zipfile

zip_name=r'C:/Users/user/Documents/data-science-hw/iis_airbox_202009{}.zip'
for i in range(1,31):
    try:
        unzip=zipfile.ZipFile(zip_name.format(str(i).zfill(2)),'r')
        unzip.extractall()
        unzip.close()
    except:
        pass
#remove 5 25

# %%
zip_name=r'C:/Users/user/Documents/data-science-hw/EPA_OD_202009.zip'
unzip=zipfile.ZipFile(zip_name.format(str(i).zfill(2)),'r')
unzip.extractall()
unzip.close()

# %%
import numpy as np
import pandas as pd

# %%
csv_name=r'C:/Users/user/Documents/data-science-hw/iis_airbox_202009{}.csv'
school_df=pd.read_csv(csv_name.format('01'))
for i in range(1,31):
    try:
        tmp_read=pd.read_csv(csv_name.format(str(i).zfill(2)))
        school_df=pd.concat([school_df,tmp_read],verify_integrity=True,join="inner", ignore_index = True)
    except:
        pass
# school_df

# %%
csv_name=r'C:/Users/user/Documents/data-science-hw/EPA_OD_202009.csv'
nation_df=pd.read_csv(csv_name.format('01'))
# nation_df

# %%
school_df_hwsh_mask=school_df.SiteName.str.contains('臺中市立惠文高中')
nation_df_cm_mask=nation_df.SiteName.str.contains('忠明')

# %%
school_df_hwsh=school_df[school_df_hwsh_mask]
print("Q1")
school_df_hwsh
# Out:
# Q1
#             device_id        SiteName PM25            timestamp
# 1188     08BEAC0A003E        臺中市立惠文高中   16  2020-09-01 00:07:07
# 2822     08BEAC0A003E        臺中市立惠文高中   16  2020-09-01 00:17:54
# 4854     08BEAC0A003E        臺中市立惠文高中   18  2020-09-01 00:28:41
# 6719     08BEAC0A003E        臺中市立惠文高中   18  2020-09-01 00:39:29
# 7344     08BEAC0A003E        臺中市立惠文高中   17  2020-09-01 00:44:55
# ...               ...             ...  ...                  ...
# 8677572  08BEAC0A003E  臺中市立惠文高中(2019)   30  2020-09-30 07:07:58
# 8686333  08BEAC0A003E  臺中市立惠文高中(2019)   27  2020-09-30 08:29:36
# 8707631  08BEAC0A003E  臺中市立惠文高中(2019)   80  2020-09-30 09:57:49
# 8710968  08BEAC0A003E  臺中市立惠文高中(2019)   22  2020-09-30 10:09:24
# 8717017  08BEAC0A003E  臺中市立惠文高中(2019)   10  2020-09-30 10:41:10
#
# [4730 rows x 4 columns]

# %%
nation_df_cm=nation_df[nation_df_cm_mask]
print("Q1")
nation_df_cm
# Out:
# Q1
#       SiteName County   AQI Pollutant Status  SO2    CO  CO_8hr    O3  O3_8hr  \
# 4           忠明    臺中市  29.0       NaN     良好  2.5  0.19     0.2  18.0    26.0
# 89          忠明    臺中市  29.0       NaN     良好  2.3  0.16     0.2  21.0    23.0
# 206         忠明    臺中市  28.0       NaN     良好  1.7  0.11     0.2  22.0    22.0
# 266         忠明    臺中市  29.0       NaN     良好  1.9  0.11     0.2  20.0    21.0
# 332         忠明    臺中市  30.0       NaN     良好  2.0  0.09     0.2  19.0    20.0
# ...        ...    ...   ...       ...    ...  ...   ...     ...   ...     ...
# 50882       忠明    臺中市  48.0       NaN     良好  2.7  0.40     0.3  21.0    52.0
# 50970       忠明    臺中市  44.0       NaN     良好  3.1  0.33     0.3  19.0    47.0
# 51010       忠明    臺中市  43.0       NaN     良好  2.8  0.39     0.3  14.0    41.0
# 51105       忠明    臺中市  45.0       NaN     良好  3.0  0.41     0.3  12.0    33.0
# 51219       忠明    臺中市  45.0       NaN     良好  2.9  0.35     0.4  14.0    26.0
#
# ...

# %%
# move day 5 and day 25
nation_df_cm=nation_df_cm[~nation_df_cm['PublishTime'].str.contains('2020-09-05')]
nation_df_cm=nation_df_cm[~nation_df_cm['PublishTime'].str.contains('2020-09-25')]
nation_df_cm['day']=nation_df_cm['PublishTime'].str.split(' ',expand=True)[0]
nation_df_cm['day']=nation_df_cm['day'].str.split('-',expand=True)[2]
nation_df_cm['hour']=nation_df_cm['PublishTime'].str.split(' ',expand=True)[1]
nation_df_cm['hour']=nation_df_cm['hour'].str.split(':',expand=True)[0].astype(int)

# nation_df_cm

# %%
school_df_hwsh['time']=school_df_hwsh['timestamp'].str.split(' ',expand=True)[1]
school_df_hwsh['hour']=(school_df_hwsh['time'].str.split(':',expand=True)[0]).astype(int)+1
school_df_hwsh['PM25']=school_df_hwsh['PM25'].astype(float)
school_df_hwsh['y-m-d']=school_df_hwsh['timestamp'].str.split(' ',expand=True)[0]
school_df_hwsh['day']=school_df_hwsh['y-m-d'].str.split('-',expand=True)[2]
# school_df_hwsh

# %%
school_df_hwsh_gr=school_df_hwsh.groupby(['day','hour'])
for k,i in school_df_hwsh_gr:
    # print(school_df_hwsh_gr.get_group(k))
# Out:
#   File "<ipython-input-71-dca91060cb9e>", line 3
#     # print(school_df_hwsh_gr.get_group(k))
#                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
# school_df_hwsh_gr_avg=school_df_hwsh_gr.PM25.mean()
school_df_hwsh_gr_avg=school_df_hwsh_gr.agg("mean")

# school_df_hwsh_gr_avg
# school_df_hwsh_gr_avg=pd.DataFrame(school_df_hwsh_gr_avg)
school_df_hwsh_gr_avg=school_df_hwsh_gr_avg.reset_index()
# school_df_hwsh_gr_avg

# %%
#Q2
import matplotlib.pyplot as plt
plt.style.use("bmh")
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False 
# %matplotlib inline
plt.title("pm25分布圖")
# plt.ylabel("濃度")
plt.scatter(school_df_hwsh_gr_avg.day,school_df_hwsh_gr_avg.PM25,label="臺中市立惠⽂⾼中pm25")
# plt.show()
# plt.title("忠明測站pm25")
plt.scatter(nation_df_cm.day,nation_df_cm["PM2.5"],label="忠明測站pm25")
plt.ylabel("濃度")
plt.xlabel("日期")
plt.legend(loc='upper right')
plt.show()
print("Q2")
# Out:
# Q2

# %%
from sklearn.datasets import load_diabetes

import pandas as pd
X, y = load_diabetes(return_X_y=True)
def loss_fun(y_true, y_pred):
    delta=5
    error = y_true - y_pred
    resolt = []
    for x in error:
        resolt.append(0.5*x**2 if x<=delta else 0.5*(abs(x)-0.5*delta))
    resolt = np.array(resolt)
    return(resolt)
def empirical_risk(theta, x, y):
    X = np.column_stack((np.ones_like(y), x))
    y_pred = X @ theta.T
    return np.mean(loss_fun(y, y_pred))

# %%
#Q3
from autograd import grad

from scipy.optimize import minimize
mini=999999

res=pd.merge(school_df_hwsh_gr_avg,nation_df_cm,on='day',how='inner')
res

theta_0 = np.array([0,0])

grad_fun2=grad(empirical_risk)

res2=minimize(empirical_risk,theta_0,(school_df_hwsh_gr_avg.PM25,nation_df_cm["PM2.5"]),method='CG',jac=grad_fun2)

res2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-2d5ad7098863> in <module>
#      12 grad_fun2=grad(empirical_risk)
#      13
# ---> 14 res2=minimize(empirical_risk,theta_0,(school_df_hwsh_gr_avg.PM25,nation_df_cm["PM2.5"]),method='CG',jac=grad_fun2)
#      15
#      16 res2
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608         return _minimize_powell(fun, x0, args, callback, bounds, **options)
#     609     elif meth == 'cg':
# --> 610         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     611     elif meth == 'bfgs':
#     612         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#
# ...
